# %%
pip install semantic-kernel
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 894.8/894.8 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 8.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 27.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 26.0 MB/s eta 0:00:00
# ...
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14419 sha256=3abc47fe2ed48cf1870f08f5c3ebb78cc2bd0dc10b0dcb7bf4e57cb59fc8e49b
#   Stored in directory: /Users/aakashrajendran/Library/Caches/pip/wheels/53/22/e8/004be7e776e11480a3d670f9dd2488a13794d4de4d6290afa5
# ...

# %%
from semantic_kernel import Kernel
kernel = Kernel()
